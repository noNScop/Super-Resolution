# %%
import os
import math
import glob
import torch
import random
import numpy as np
import pandas as pd
from PIL import Image
import torch.nn as nn
from tqdm.auto import tqdm
from torch.optim import Adam
from torchvision.transforms import v2
from torch.amp import autocast, GradScaler
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import Dataset, DataLoader
from torchmetrics.image import PeakSignalNoiseRatio
from torchmetrics.image import StructuralSimilarityIndexMeasure
from torchmetrics.image.lpip import LearnedPerceptualImagePatchSimilarity

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
HR_train_paths = sorted(glob.glob("../data/DIV2K_train_HR/*.png"))
X2_train_paths = sorted(glob.glob("../data/DIV2K_train_LR_bicubic/X2/*.png"))
X4_train_paths = sorted(glob.glob("../data/DIV2K_train_LR_bicubic/X4/*.png"))
X8_train_paths = sorted(glob.glob("../data/DIV2K_train_LR_bicubic/X8/*.png"))
X16_train_paths = sorted(glob.glob("../data/DIV2K_train_LR_bicubic/X16/*.png"))
X32_train_paths = sorted(glob.glob("../data/DIV2K_train_LR_bicubic/X32/*.png"))
X64_train_paths = sorted(glob.glob("../data/DIV2K_train_LR_bicubic/X64/*.png"))

HR_valid_paths = sorted(glob.glob("../data/DIV2K_valid_HR/*.png"))
X2_valid_paths = sorted(glob.glob("../data/DIV2K_valid_LR_bicubic/X2/*.png"))
X4_valid_paths = sorted(glob.glob("../data/DIV2K_valid_LR_bicubic/X4/*.png"))
X8_valid_paths = sorted(glob.glob("../data/DIV2K_valid_LR_bicubic/X8/*.png"))
X16_valid_paths = sorted(glob.glob("../data/DIV2K_valid_LR_bicubic/X16/*.png"))
X32_valid_paths = sorted(glob.glob("../data/DIV2K_valid_LR_bicubic/X32/*.png"))
X64_valid_paths = sorted(glob.glob("../data/DIV2K_valid_LR_bicubic/X64/*.png"))

# %%
class DenseBlock(nn.Module):
    def __init__(self):
        super().__init__()
        self.blocks = nn.Sequential()
        for i in range(1,5):
            self.blocks.append(
                nn.Sequential(
                    nn.Conv2d(i * 64, 64, 3, stride=1, padding='same'),
                    nn.LeakyReLU()
                )
            )

        self.blocks.append(nn.Conv2d(5 * 64, 64, 3, stride=1, padding='same'))

    def forward(self, x):
        x1 = self.blocks[0](x)
        x = torch.cat([x, x1], dim=1)
        x2 = self.blocks[1](x)
        x = torch.cat([x, x2], dim=1)
        x3 = self.blocks[2](x)
        x = torch.cat([x, x3], dim=1)
        x4 = self.blocks[3](x)
        x = torch.cat([x, x4], dim=1)
        return self.blocks[4](x)
        
class ESRGAN(nn.Module):
    def __init__(self, n: int):
        """
        Enhanced Deep Residual Network with Residual in Residual Dense Block a.k.a.
        Enhanced Super Resolution Generative Adversarial Networks
        Args:
            n: scaling factor
        """
        super().__init__()
        self.DIV2K_RGB = torch.tensor([0.44882884613943946, 0.43713809810624193, 0.4040371984052683]).view(1, 3, 1, 1).to(device)
        
        self.expand = nn.Sequential(
            nn.Conv2d(3, 64, 9, stride=1, padding='same'),
            nn.PReLU()
        )

        self.residual_blocks = nn.Sequential()
        for _ in range(23):
            self.residual_blocks.append(DenseBlock())

        self.residual_blocks.append(nn.Conv2d(64, 64, 3, stride=1, padding='same'))

        self.upscaling_head = nn.Sequential()
        for _ in range(int(math.log2(n))):
            self.upscaling_head.append(nn.Conv2d(64, 256, 3, stride=1, padding='same'))
            self.upscaling_head.append(nn.PixelShuffle(2))
            self.upscaling_head.append(nn.PReLU())
            
        self.upscaling_head.append(nn.Conv2d(64, 64, 9, stride=1, padding='same'))
        self.upscaling_head.append(nn.Conv2d(64, 3, 9, stride=1, padding='same'))

    def forward(self, x):
        x = self.expand(x-self.DIV2K_RGB)
        xp = x.clone()
        for i in range(23):
            xp = xp + 0.2 * self.residual_blocks[i](xp)

        x = x + 0.2 * self.residual_blocks[23](xp)
        return self.upscaling_head(x) + self.DIV2K_RGB

# %%
class ESRGAN_Dataset(Dataset):
    def __init__(self, target_paths: list[str], scale: int, ram_limit_gb: float = 2.0):
        self.crop_size = scale * 48
        self.scale = scale

        self.rotations = [0, 90, 180, 270]
        self.transforms = v2.Compose([
            v2.PILToTensor(),
            v2.Lambda(lambda x: (x / 255.0))
        ])

        self.preloaded = {}
        self.paths = target_paths

        total_ram_used = 0
        for i, path in enumerate(tqdm(target_paths, desc="Preloading images")):
            img = Image.open(path).convert("RGB")
            total_ram_used += img.width * img.height * 3 / (1024 ** 3)  # ~size in GB

            if total_ram_used < ram_limit_gb:
                self.preloaded[i] = img
            else:
                break

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, idx):
        if idx in self.preloaded:
            target = self.preloaded[idx]
        else:
            target = Image.open(self.paths[idx]).convert("RGB")

        target = self.random_crop(target, self.crop_size)
        inp = target.resize((target.width // self.scale, target.height // self.scale), Image.BICUBIC)
        
        rotation =  random.choice(self.rotations)
        if rotation != 0:
            inp = v2.functional.rotate(inp, rotation)
            target = v2.functional.rotate(target, rotation)
        if random.randint(0, 1):
            inp = v2.functional.horizontal_flip(inp)
            target = v2.functional.horizontal_flip(target)
            
        return self.transforms(inp), self.transforms(target)

    def random_crop(self, img, size):
        w, h = img.size
        if w < size or h < size:
            img = img.resize((size, size), Image.BICUBIC)
        x = random.randint(0, w - size)
        y = random.randint(0, h - size)
        return img.crop((x, y, x + size, y + size))

    def set_scale(self, scale: int):
        self.scale = scale

    def set_crop_size(self, crop_size: int):
        self.crop_size = crop_size

# %%
psnr = PeakSignalNoiseRatio(data_range=1.0).to(device)
ssim = StructuralSimilarityIndexMeasure(data_range=1.0).to(device)
lpips = LearnedPerceptualImagePatchSimilarity(normalize=True).to(device)

# %%
transform = v2.Compose([
    v2.PILToTensor(),
    v2.Lambda(lambda x: x / 255.0)
])

# %%
def calc_metrics(model: nn.Module, target_ds: list[str], scale: int):
    transform_target = v2.Compose([
        v2.PILToTensor(),
        v2.Lambda(lambda x: x/255.0)
    ])

    transform_input = v2.Compose([
        v2.PILToTensor(),
        v2.Lambda(lambda x: (x / 255.0))
    ])

    psnr_acc = 0
    ssim_acc = 0
    lpips_acc = 0
    failed_lpips = 0

    for i in tqdm(range(len(target_ds)), leave=False):
        target_image = Image.open(target_ds[i]).convert("RGB")
        w, h = target_image.size

        w -= w % scale
        h -= h % scale
        target_image = target_image.crop((0, 0, w, h))
        
        lowres = target_image.resize((w // scale, h // scale), resample=Image.BICUBIC)
        input_tensor = transform_input(lowres).unsqueeze(0).to(device)
        target_tensor = transform_target(target_image).unsqueeze(0).to(device)

        with torch.inference_mode():
            sr = model(input_tensor).clamp(0, 1)

        psnr_acc += psnr(sr, target_tensor).item()
        ssim_acc += ssim(sr, target_tensor).item()
        
        # There are 2 images that cause lpips to fail
        try:
            x = lpips(sr, target_tensor).cpu().item()
            if np.isnan(x):
                failed_lpips += 1
                continue
                
            lpips_acc += x
        except:
            failed_lpips += 1

    lpips_acc /= len(target_ds) - failed_lpips
    psnr_acc /= len(target_ds)
    ssim_acc /= len(target_ds)
    return psnr_acc, ssim_acc, lpips_acc

# %%
def train_step(model, dataloader, optimizer, loss_fn, scaler):
    avg_psnr = 0
    avg_ssim = 0
    model.train()

    for batch, target in dataloader:
        optimizer.zero_grad(set_to_none=True)
        
        batch, target = batch.to(device), target.to(device)

        with autocast('cuda'):
            logits = model(batch)
            loss = loss_fn(logits, target)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        logits = logits.clamp(0.0, 1.0)
        target = target.clamp(0.0, 1.0)
        
        avg_psnr += psnr(logits, target).item()
        avg_ssim += ssim(logits, target).item()
        
    avg_psnr /= len(dataloader)
    avg_ssim /= len(dataloader)
    return avg_psnr, avg_ssim

def valid_step(model, dataloader, loss_fn):
    avg_psnr = 0
    avg_ssim = 0
    avg_lpips = 0
    model.eval()

    with torch.inference_mode():
        for batch, target in dataloader:
            batch, target = batch.to(device), target.to(device)

            logits = model(batch)
            
            logits = logits.clamp(0.0, 1.0)
            target = target.clamp(0.0, 1.0)
            
            avg_psnr += psnr(logits, target).item()
            avg_ssim += ssim(logits, target).item()
            avg_lpips += lpips(logits, target).item()

    avg_psnr /= len(dataloader)
    avg_ssim /= len(dataloader)
    avg_lpips /= len(dataloader)

        
    return avg_psnr, avg_ssim, avg_lpips

# %%
def train(model, train_dl, valid_dl, optimizer, scheduler: StepLR, loss_fn, epochs, start_checkpoint=None):
    os.makedirs('../tmp_model_checkpoints', exist_ok=True)
    counter = 0 # count epochs without printing training stats
    scaler = GradScaler('cuda')
    
    if start_checkpoint:
        start_epoch = start_checkpoint['epoch']
        best_psnr = start_checkpoint['best_psnr']
        best_ssim = start_checkpoint['best_ssim']
        best_lpips = start_checkpoint['best_lpips']
        scaler.load_state_dict(start_checkpoint['scaler_state_dict'])
    else:
        start_epoch = 0
        best_psnr = 0
        best_ssim = 0
        best_lpips = float('inf')
        
    log_freq = (epochs - start_epoch) // 30 # how often to print stats when no progress is made
    
    for epoch in tqdm(range(start_epoch, epochs), desc="Epochs"):
        counter += 1
        train_psnr, train_ssim = train_step(
            model,
            train_dl,
            optimizer,
            loss_fn,
            scaler
        )

        valid_psnr, valid_ssim, valid_lpips = valid_step(
            model,
            valid_dl,
            loss_fn,
        )

        scheduler.step()

        progress = False
        
        if valid_psnr > best_psnr:
            progress = True
            best_psnr = valid_psnr
            checkpoint = {
                'epoch': epoch,
                'best_psnr': best_psnr,
                'best_ssim': best_ssim,
                'best_lpips': best_lpips,
                'model_state_dict': model._orig_mod.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'scheduler_state_dict': scheduler.state_dict(),
                'scaler_state_dict': scaler.state_dict()
            }
            torch.save(checkpoint, f'../tmp_model_checkpoints/best_psnr.pth')

        if valid_ssim > best_ssim:
            progress = True
            best_ssim = valid_ssim
            checkpoint = {
                'epoch': epoch,
                'best_psnr': best_psnr,
                'best_ssim': best_ssim,
                'best_lpips': best_lpips,
                'model_state_dict': model._orig_mod.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'scheduler_state_dict': scheduler.state_dict(),
                'scaler_state_dict': scaler.state_dict()
            }
            torch.save(checkpoint, f'../tmp_model_checkpoints/best_ssim.pth')

        if valid_lpips < best_lpips:
            progress = True
            best_lpips = valid_lpips
            checkpoint = {
                'epoch': epoch,
                'best_psnr': best_psnr,
                'best_ssim': best_ssim,
                'best_lpips': best_lpips,
                'model_state_dict': model._orig_mod.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'scheduler_state_dict': scheduler.state_dict(),
                'scaler_state_dict': scaler.state_dict()
            }
            torch.save(checkpoint, f'../tmp_model_checkpoints/best_lpips.pth')

        if epoch == epochs-1:
            checkpoint = {
                'epoch': epoch,
                'best_psnr': best_psnr,
                'best_ssim': best_ssim,
                'best_lpips': best_lpips,
                'model_state_dict': model._orig_mod.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'scheduler_state_dict': scheduler.state_dict(),
                'scaler_state_dict': scaler.state_dict()
            }
            torch.save(checkpoint, f'../tmp_model_checkpoints/last.pth')
            
        if progress or counter >= log_freq:
            counter = 0
            print(
                f"Epoch: {epoch+1} | "
                f"learning rate: {scheduler.get_last_lr()[0]:.6f} | "
                f"[train] PSNR: {train_psnr:.4f} | "
                f"[train] SSIM: {train_ssim:.4f} | "
                f"[valid] PSNR: {valid_psnr:.4f} | "
                f"[valid] SSIM: {valid_ssim:.4f} | "
                f"[valid] LPIPS: {valid_lpips:.4f}"
            )

# %% [markdown]
# ## Training

# %%
valid_ds = ESRGAN_Dataset(HR_valid_paths, 2, ram_limit_gb=1)
# Out:
# Preloading images:   0%|          | 0/100 [00:00<?, ?it/s]

# %%
train_ds = ESRGAN_Dataset(HR_train_paths, 2, ram_limit_gb=8)
# Out:
# Preloading images:   0%|          | 0/800 [00:00<?, ?it/s]

# %% [markdown]
# ### Day 1

# %%
train_dl = DataLoader(train_ds, batch_size=16, shuffle=True, num_workers=os.cpu_count()-1)
valid_dl = DataLoader(valid_ds, batch_size=16, shuffle=False, num_workers=os.cpu_count()-1)

model = torch.compile(ESRGAN(2).to(device))
loss_fn = nn.L1Loss()
optimizer = Adam(model.parameters(), lr=2e-4)
scheduler = StepLR(optimizer, step_size=4000, gamma=0.5)

train(model, train_dl, valid_dl, optimizer, scheduler, loss_fn, 3333)
# Out:
# Epochs:   0%|          | 0/3333 [00:00<?, ?it/s]
# W0523 07:50:34.369000 2685 torch/_inductor/utils.py:1250] [0/0] Not enough SMs to use max_autotune_gemm mode
# Epoch: 1 | learning rate: 0.000200 | [train] PSNR: 19.2574 | [train] SSIM: 0.5180 | [valid] PSNR: 20.9305 | [valid] SSIM: 0.5610 | [valid] LPIPS: 0.6127
# Epoch: 2 | learning rate: 0.000200 | [train] PSNR: 21.7832 | [train] SSIM: 0.6175 | [valid] PSNR: 21.1425 | [valid] SSIM: 0.6097 | [valid] LPIPS: 0.4966
# Epoch: 3 | learning rate: 0.000200 | [train] PSNR: 23.4297 | [train] SSIM: 0.6826 | [valid] PSNR: 24.3567 | [valid] SSIM: 0.7129 | [valid] LPIPS: 0.4039
# Epoch: 4 | learning rate: 0.000200 | [train] PSNR: 24.3505 | [train] SSIM: 0.7334 | [valid] PSNR: 24.9800 | [valid] SSIM: 0.7403 | [valid] LPIPS: 0.3672
# Epoch: 5 | learning rate: 0.000200 | [train] PSNR: 25.4929 | [train] SSIM: 0.7706 | [valid] PSNR: 26.1496 | [valid] SSIM: 0.7861 | [valid] LPIPS: 0.3219
# Epoch: 6 | learning rate: 0.000200 | [train] PSNR: 26.0246 | [train] SSIM: 0.8002 | [valid] PSNR: 26.3174 | [valid] SSIM: 0.8096 | [valid] LPIPS: 0.2705
# Epoch: 7 | learning rate: 0.000200 | [train] PSNR: 26.3079 | [train] SSIM: 0.8113 | [valid] PSNR: 27.1863 | [valid] SSIM: 0.8128 | [valid] LPIPS: 0.2428
# Epoch: 8 | learning rate: 0.000200 | [train] PSNR: 26.9950 | [train] SSIM: 0.8338 | [valid] PSNR: 27.4828 | [valid] SSIM: 0.8361 | [valid] LPIPS: 0.2206
# Epoch: 9 | learning rate: 0.000200 | [train] PSNR: 27.1253 | [train] SSIM: 0.8390 | [valid] PSNR: 27.3491 | [valid] SSIM: 0.8352 | [valid] LPIPS: 0.1957
# Epoch: 10 | learning rate: 0.000200 | [train] PSNR: 27.9400 | [train] SSIM: 0.8558 | [valid] PSNR: 28.1054 | [valid] SSIM: 0.8519 | [valid] LPIPS: 0.1485
# Epoch: 11 | learning rate: 0.000200 | [train] PSNR: 27.7443 | [train] SSIM: 0.8596 | [valid] PSNR: 28.1636 | [valid] SSIM: 0.8549 | [valid] LPIPS: 0.1488
# Epoch: 12 | learning rate: 0.000200 | [train] PSNR: 27.9735 | [train] SSIM: 0.8684 | [valid] PSNR: 27.6395 | [valid] SSIM: 0.8516 | [valid] LPIPS: 0.1425
# Epoch: 13 | learning rate: 0.000200 | [train] PSNR: 27.8076 | [train] SSIM: 0.8610 | [valid] PSNR: 26.9913 | [valid] SSIM: 0.8464 | [valid] LPIPS: 0.1355
# Epoch: 14 | learning rate: 0.000200 | [train] PSNR: 28.3929 | [train] SSIM: 0.8731 | [valid] PSNR: 27.7789 | [valid] SSIM: 0.8609 | [valid] LPIPS: 0.1312
# Epoch: 15 | learning rate: 0.000200 | [train] PSNR: 27.8995 | [train] SSIM: 0.8702 | [valid] PSNR: 28.0465 | [valid] SSIM: 0.8659 | [valid] LPIPS: 0.1170
# Epoch: 16 | learning rate: 0.000200 | [train] PSNR: 27.9632 | [train] SSIM: 0.8713 | [valid] PSNR: 28.3817 | [valid] SSIM: 0.8825 | [valid] LPIPS: 0.1025
# Epoch: 17 | learning rate: 0.000200 | [train] PSNR: 28.6657 | [train] SSIM: 0.8818 | [valid] PSNR: 29.1329 | [valid] SSIM: 0.8825 | [valid] LPIPS: 0.1075
# Epoch: 18 | learning rate: 0.000200 | [train] PSNR: 28.6983 | [train] SSIM: 0.8817 | [valid] PSNR: 29.3987 | [valid] SSIM: 0.8875 | [valid] LPIPS: 0.0945
# Epoch: 23 | learning rate: 0.000200 | [train] PSNR: 28.4702 | [train] SSIM: 0.8829 | [valid] PSNR: 29.9226 | [valid] SSIM: 0.8754 | [valid] LPIPS: 0.1125
# Epoch: 29 | learning rate: 0.000200 | [train] PSNR: 29.1663 | [train] SSIM: 0.8932 | [valid] PSNR: 28.4691 | [valid] SSIM: 0.8908 | [valid] LPIPS: 0.1080
# Epoch: 30 | learning rate: 0.000200 | [train] PSNR: 29.3496 | [train] SSIM: 0.8949 | [valid] PSNR: 30.0420 | [valid] SSIM: 0.8987 | [valid] LPIPS: 0.0908
# Epoch: 31 | learning rate: 0.000200 | [train] PSNR: 29.1963 | [train] SSIM: 0.8990 | [valid] PSNR: 30.1490 | [valid] SSIM: 0.9020 | [valid] LPIPS: 0.0870
# Epoch: 34 | learning rate: 0.000200 | [train] PSNR: 28.9322 | [train] SSIM: 0.8910 | [valid] PSNR: 30.1842 | [valid] SSIM: 0.8924 | [valid] LPIPS: 0.0930
# Epoch: 36 | learning rate: 0.000200 | [train] PSNR: 29.4757 | [train] SSIM: 0.8987 | [valid] PSNR: 30.3902 | [valid] SSIM: 0.9063 | [valid] LPIPS: 0.0893
# Epoch: 40 | learning rate: 0.000200 | [train] PSNR: 29.5271 | [train] SSIM: 0.8974 | [valid] PSNR: 29.5087 | [valid] SSIM: 0.8933 | [valid] LPIPS: 0.0863
# Epoch: 41 | learning rate: 0.000200 | [train] PSNR: 29.8566 | [train] SSIM: 0.9037 | [valid] PSNR: 30.1932 | [valid] SSIM: 0.9079 | [valid] LPIPS: 0.0840
# Epoch: 43 | learning rate: 0.000200 | [train] PSNR: 29.5133 | [train] SSIM: 0.9052 | [valid] PSNR: 29.7192 | [valid] SSIM: 0.8979 | [valid] LPIPS: 0.0818
# Epoch: 44 | learning rate: 0.000200 | [train] PSNR: 29.6912 | [train] SSIM: 0.9024 | [valid] PSNR: 29.7960 | [valid] SSIM: 0.9047 | [valid] LPIPS: 0.0780
# Epoch: 46 | learning rate: 0.000200 | [train] PSNR: 29.8272 | [train] SSIM: 0.9005 | [valid] PSNR: 30.6517 | [valid] SSIM: 0.9105 | [valid] LPIPS: 0.0847
# Epoch: 53 | learning rate: 0.000200 | [train] PSNR: 29.7688 | [train] SSIM: 0.9046 | [valid] PSNR: 29.7585 | [valid] SSIM: 0.9132 | [valid] LPIPS: 0.0710
# Epoch: 60 | learning rate: 0.000200 | [train] PSNR: 29.8366 | [train] SSIM: 0.9055 | [valid] PSNR: 30.9646 | [valid] SSIM: 0.9126 | [valid] LPIPS: 0.0742
# Epoch: 63 | learning rate: 0.000200 | [train] PSNR: 30.2325 | [train] SSIM: 0.9127 | [valid] PSNR: 30.4619 | [valid] SSIM: 0.9082 | [valid] LPIPS: 0.0671
# Epoch: 64 | learning rate: 0.000200 | [train] PSNR: 30.1951 | [train] SSIM: 0.9104 | [valid] PSNR: 30.8575 | [valid] SSIM: 0.9193 | [valid] LPIPS: 0.0684
# Epoch: 74 | learning rate: 0.000200 | [train] PSNR: 30.0814 | [train] SSIM: 0.9099 | [valid] PSNR: 31.3652 | [valid] SSIM: 0.9258 | [valid] LPIPS: 0.0659
# Epoch: 82 | learning rate: 0.000200 | [train] PSNR: 29.6337 | [train] SSIM: 0.9082 | [valid] PSNR: 30.6125 | [valid] SSIM: 0.9105 | [valid] LPIPS: 0.0649
# Epoch: 90 | learning rate: 0.000200 | [train] PSNR: 30.4606 | [train] SSIM: 0.9151 | [valid] PSNR: 31.4162 | [valid] SSIM: 0.9095 | [valid] LPIPS: 0.0745
# Epoch: 91 | learning rate: 0.000200 | [train] PSNR: 30.4079 | [train] SSIM: 0.9140 | [valid] PSNR: 31.6415 | [valid] SSIM: 0.9281 | [valid] LPIPS: 0.0618
# Epoch: 105 | learning rate: 0.000200 | [train] PSNR: 30.6012 | [train] SSIM: 0.9201 | [valid] PSNR: 31.6857 | [valid] SSIM: 0.9208 | [valid] LPIPS: 0.0634
# Epoch: 115 | learning rate: 0.000200 | [train] PSNR: 30.4372 | [train] SSIM: 0.9158 | [valid] PSNR: 32.1286 | [valid] SSIM: 0.9247 | [valid] LPIPS: 0.0656
# Epoch: 132 | learning rate: 0.000200 | [train] PSNR: 30.7501 | [train] SSIM: 0.9219 | [valid] PSNR: 31.3148 | [valid] SSIM: 0.9301 | [valid] LPIPS: 0.0531
# Epoch: 134 | learning rate: 0.000200 | [train] PSNR: 30.2994 | [train] SSIM: 0.9172 | [valid] PSNR: 32.1851 | [valid] SSIM: 0.9310 | [valid] LPIPS: 0.0561
# Epoch: 222 | learning rate: 0.000200 | [train] PSNR: 31.4133 | [train] SSIM: 0.9263 | [valid] PSNR: 32.1014 | [valid] SSIM: 0.9318 | [valid] LPIPS: 0.0558
# Epoch: 225 | learning rate: 0.000200 | [train] PSNR: 30.8744 | [train] SSIM: 0.9257 | [valid] PSNR: 32.2431 | [valid] SSIM: 0.9264 | [valid] LPIPS: 0.0624
# Epoch: 226 | learning rate: 0.000200 | [train] PSNR: 30.7134 | [train] SSIM: 0.9238 | [valid] PSNR: 31.7972 | [valid] SSIM: 0.9320 | [valid] LPIPS: 0.0593
# Epoch: 238 | learning rate: 0.000200 | [train] PSNR: 31.5937 | [train] SSIM: 0.9242 | [valid] PSNR: 31.8428 | [valid] SSIM: 0.9338 | [valid] LPIPS: 0.0557
# Epoch: 239 | learning rate: 0.000200 | [train] PSNR: 31.0924 | [train] SSIM: 0.9242 | [valid] PSNR: 32.0774 | [valid] SSIM: 0.9362 | [valid] LPIPS: 0.0562
# Epoch: 242 | learning rate: 0.000200 | [train] PSNR: 30.6225 | [train] SSIM: 0.9213 | [valid] PSNR: 32.8136 | [valid] SSIM: 0.9317 | [valid] LPIPS: 0.0577
# Epoch: 353 | learning rate: 0.000200 | [train] PSNR: 31.6201 | [train] SSIM: 0.9308 | [valid] PSNR: 31.7025 | [valid] SSIM: 0.9352 | [valid] LPIPS: 0.0588
# Epoch: 390 | learning rate: 0.000200 | [train] PSNR: 31.3366 | [train] SSIM: 0.9292 | [valid] PSNR: 32.3344 | [valid] SSIM: 0.9329 | [valid] LPIPS: 0.0516
# Epoch: 407 | learning rate: 0.000200 | [train] PSNR: 31.6030 | [train] SSIM: 0.9281 | [valid] PSNR: 32.4917 | [valid] SSIM: 0.9369 | [valid] LPIPS: 0.0552
# Epoch: 460 | learning rate: 0.000200 | [train] PSNR: 31.1260 | [train] SSIM: 0.9258 | [valid] PSNR: 32.0432 | [valid] SSIM: 0.9270 | [valid] LPIPS: 0.0507
# Epoch: 462 | learning rate: 0.000200 | [train] PSNR: 31.3339 | [train] SSIM: 0.9287 | [valid] PSNR: 32.3322 | [valid] SSIM: 0.9398 | [valid] LPIPS: 0.0523
# Epoch: 477 | learning rate: 0.000200 | [train] PSNR: 31.6803 | [train] SSIM: 0.9298 | [valid] PSNR: 31.5970 | [valid] SSIM: 0.9378 | [valid] LPIPS: 0.0505
# Epoch: 480 | learning rate: 0.000200 | [train] PSNR: 31.8961 | [train] SSIM: 0.9323 | [valid] PSNR: 32.4998 | [valid] SSIM: 0.9376 | [valid] LPIPS: 0.0495
# Epoch: 502 | learning rate: 0.000200 | [train] PSNR: 31.8201 | [train] SSIM: 0.9327 | [valid] PSNR: 32.7697 | [valid] SSIM: 0.9396 | [valid] LPIPS: 0.0493
# Epoch: 504 | learning rate: 0.000200 | [train] PSNR: 31.3676 | [train] SSIM: 0.9304 | [valid] PSNR: 32.8246 | [valid] SSIM: 0.9340 | [valid] LPIPS: 0.0625
# Epoch: 537 | learning rate: 0.000200 | [train] PSNR: 31.5121 | [train] SSIM: 0.9299 | [valid] PSNR: 32.9979 | [valid] SSIM: 0.9289 | [valid] LPIPS: 0.0598
# Epoch: 552 | learning rate: 0.000200 | [train] PSNR: 31.6160 | [train] SSIM: 0.9301 | [valid] PSNR: 33.0173 | [valid] SSIM: 0.9365 | [valid] LPIPS: 0.0574
# Epoch: 565 | learning rate: 0.000200 | [train] PSNR: 31.2264 | [train] SSIM: 0.9291 | [valid] PSNR: 33.3153 | [valid] SSIM: 0.9386 | [valid] LPIPS: 0.0561
# Epoch: 645 | learning rate: 0.000200 | [train] PSNR: 31.5488 | [train] SSIM: 0.9279 | [valid] PSNR: 33.6126 | [valid] SSIM: 0.9411 | [valid] LPIPS: 0.0513
# Epoch: 756 | learning rate: 0.000200 | [train] PSNR: 31.6197 | [train] SSIM: 0.9323 | [valid] PSNR: 31.9248 | [valid] SSIM: 0.9243 | [valid] LPIPS: 0.0627
# Epoch: 763 | learning rate: 0.000200 | [train] PSNR: 31.8165 | [train] SSIM: 0.9343 | [valid] PSNR: 33.2222 | [valid] SSIM: 0.9446 | [valid] LPIPS: 0.0459
# Epoch: 874 | learning rate: 0.000200 | [train] PSNR: 31.8026 | [train] SSIM: 0.9346 | [valid] PSNR: 31.6130 | [valid] SSIM: 0.9336 | [valid] LPIPS: 0.0567
# Epoch: 981 | learning rate: 0.000200 | [train] PSNR: 31.3162 | [train] SSIM: 0.9320 | [valid] PSNR: 33.7797 | [valid] SSIM: 0.9382 | [valid] LPIPS: 0.0530
# Epoch: 1086 | learning rate: 0.000200 | [train] PSNR: 32.0804 | [train] SSIM: 0.9333 | [valid] PSNR: 33.5004 | [valid] SSIM: 0.9414 | [valid] LPIPS: 0.0449
# Epoch: 1197 | learning rate: 0.000200 | [train] PSNR: 32.1624 | [train] SSIM: 0.9358 | [valid] PSNR: 31.1471 | [valid] SSIM: 0.9282 | [valid] LPIPS: 0.0597
# Epoch: 1308 | learning rate: 0.000200 | [train] PSNR: 31.9560 | [train] SSIM: 0.9346 | [valid] PSNR: 31.6781 | [valid] SSIM: 0.9331 | [valid] LPIPS: 0.0548
# Epoch: 1419 | learning rate: 0.000200 | [train] PSNR: 31.6591 | [train] SSIM: 0.9311 | [valid] PSNR: 33.1175 | [valid] SSIM: 0.9408 | [valid] LPIPS: 0.0497
# Epoch: 1530 | learning rate: 0.000200 | [train] PSNR: 31.9385 | [train] SSIM: 0.9353 | [valid] PSNR: 31.4483 | [valid] SSIM: 0.9251 | [valid] LPIPS: 0.0598
# Epoch: 1637 | learning rate: 0.000200 | [train] PSNR: 32.1283 | [train] SSIM: 0.9353 | [valid] PSNR: 32.4303 | [valid] SSIM: 0.9441 | [valid] LPIPS: 0.0434
# Epoch: 1748 | learning rate: 0.000200 | [train] PSNR: 31.9112 | [train] SSIM: 0.9336 | [valid] PSNR: 32.3044 | [valid] SSIM: 0.9239 | [valid] LPIPS: 0.0593
# Epoch: 1768 | learning rate: 0.000200 | [train] PSNR: 31.8038 | [train] SSIM: 0.9353 | [valid] PSNR: 34.0457 | [valid] SSIM: 0.9389 | [valid] LPIPS: 0.0573
# Epoch: 1879 | learning rate: 0.000200 | [train] PSNR: 31.9235 | [train] SSIM: 0.9388 | [valid] PSNR: 32.9674 | [valid] SSIM: 0.9348 | [valid] LPIPS: 0.0528
# Epoch: 1980 | learning rate: 0.000200 | [train] PSNR: 32.3298 | [train] SSIM: 0.9392 | [valid] PSNR: 33.3549 | [valid] SSIM: 0.9458 | [valid] LPIPS: 0.0515
# Epoch: 2091 | learning rate: 0.000200 | [train] PSNR: 32.0640 | [train] SSIM: 0.9373 | [valid] PSNR: 32.5677 | [valid] SSIM: 0.9374 | [valid] LPIPS: 0.0555
# Epoch: 2202 | learning rate: 0.000200 | [train] PSNR: 31.6112 | [train] SSIM: 0.9346 | [valid] PSNR: 31.3242 | [valid] SSIM: 0.9259 | [valid] LPIPS: 0.0645
# Epoch: 2313 | learning rate: 0.000200 | [train] PSNR: 31.7646 | [train] SSIM: 0.9358 | [valid] PSNR: 32.4914 | [valid] SSIM: 0.9328 | [valid] LPIPS: 0.0574
# Epoch: 2424 | learning rate: 0.000200 | [train] PSNR: 32.1767 | [train] SSIM: 0.9353 | [valid] PSNR: 32.0855 | [valid] SSIM: 0.9331 | [valid] LPIPS: 0.0601
# Epoch: 2535 | learning rate: 0.000200 | [train] PSNR: 31.9566 | [train] SSIM: 0.9365 | [valid] PSNR: 33.1712 | [valid] SSIM: 0.9372 | [valid] LPIPS: 0.0547
# Epoch: 2646 | learning rate: 0.000200 | [train] PSNR: 32.1169 | [train] SSIM: 0.9388 | [valid] PSNR: 32.1991 | [valid] SSIM: 0.9342 | [valid] LPIPS: 0.0593
# Epoch: 2740 | learning rate: 0.000200 | [train] PSNR: 32.4952 | [train] SSIM: 0.9377 | [valid] PSNR: 33.6791 | [valid] SSIM: 0.9500 | [valid] LPIPS: 0.0444
# Epoch: 2851 | learning rate: 0.000200 | [train] PSNR: 32.0608 | [train] SSIM: 0.9362 | [valid] PSNR: 32.8177 | [valid] SSIM: 0.9428 | [valid] LPIPS: 0.0496
# Epoch: 2962 | learning rate: 0.000200 | [train] PSNR: 32.1375 | [train] SSIM: 0.9385 | [valid] PSNR: 32.4865 | [valid] SSIM: 0.9341 | [valid] LPIPS: 0.0585
# Epoch: 3073 | learning rate: 0.000200 | [train] PSNR: 32.2195 | [train] SSIM: 0.9370 | [valid] PSNR: 32.1053 | [valid] SSIM: 0.9263 | [valid] LPIPS: 0.0711
# Epoch: 3184 | learning rate: 0.000200 | [train] PSNR: 32.4855 | [train] SSIM: 0.9381 | [valid] PSNR: 31.8401 | [valid] SSIM: 0.9336 | [valid] LPIPS: 0.0532
# Epoch: 3295 | learning rate: 0.000200 | [train] PSNR: 32.2997 | [train] SSIM: 0.9384 | [valid] PSNR: 32.7665 | [valid] SSIM: 0.9360 | [valid] LPIPS: 0.0571

# %%
checkpoint = torch.load('../tmp_model_checkpoints/last.pth')
model = ESRGAN(2).to(device)
model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
model.eval();

# %%
targets = [X32_valid_paths, X16_valid_paths, X8_valid_paths, X4_valid_paths, X2_valid_paths, HR_valid_paths]

metrics_x2 = pd.DataFrame(columns=["PSNR↑", "SSIM↑", "LPIPS↓"])
for target_ds in tqdm(targets, total=6):
    metrics_x2.loc[len(metrics_x2)] = calc_metrics(model, target_ds, 2)

metrics_x2.index = [
    "31px -> 62px", "63px -> 126px", "127px -> 254px", 
    "255px -> 510px", "510px -> 1020px", "1020px -> 2040px"
]
metrics_x2
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#                       PSNR↑     SSIM↑    LPIPS↓
# 31px -> 62px      26.749013  0.881142  0.050005
# 63px -> 126px     28.033528  0.897445  0.074818
# 127px -> 254px    29.897095  0.920161  0.076518
# 255px -> 510px    31.428937  0.929166  0.075169
# 510px -> 1020px   33.283587  0.939109  0.073850
# 1020px -> 2040px  34.498609  0.936519  0.087584

# %% [markdown]
# ### Day 2

# %%
train_dl = DataLoader(train_ds, batch_size=16, shuffle=True, num_workers=os.cpu_count()-1)
valid_dl = DataLoader(valid_ds, batch_size=16, shuffle=False, num_workers=os.cpu_count()-1)

checkpoint = torch.load('../tmp_model_checkpoints/last.pth')
model = ESRGAN(2).to(device)
loss_fn = nn.L1Loss()
optimizer = Adam(model.parameters(), lr=2e-4)
scheduler = StepLR(optimizer, step_size=4000, gamma=0.5)

model.load_state_dict(checkpoint['model_state_dict'])
model = torch.compile(model)
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
scheduler.load_state_dict(checkpoint['scheduler_state_dict'])

train(model, train_dl, valid_dl, optimizer, scheduler, loss_fn, 6666, checkpoint)
# Out:
# Epochs:   0%|          | 0/3334 [00:00<?, ?it/s]
# W0527 08:09:18.368000 2936 torch/_inductor/utils.py:1250] [0/0] Not enough SMs to use max_autotune_gemm mode
# Epoch: 3443 | learning rate: 0.000200 | [train] PSNR: 29.4277 | [train] SSIM: 0.8936 | [valid] PSNR: 30.0798 | [valid] SSIM: 0.9026 | [valid] LPIPS: 0.0968
# Epoch: 3554 | learning rate: 0.000200 | [train] PSNR: 31.3929 | [train] SSIM: 0.9250 | [valid] PSNR: 31.2760 | [valid] SSIM: 0.9239 | [valid] LPIPS: 0.0607
# Epoch: 3665 | learning rate: 0.000200 | [train] PSNR: 31.8970 | [train] SSIM: 0.9350 | [valid] PSNR: 32.0994 | [valid] SSIM: 0.9364 | [valid] LPIPS: 0.0564
# Epoch: 3744 | learning rate: 0.000200 | [train] PSNR: 31.8033 | [train] SSIM: 0.9363 | [valid] PSNR: 34.1744 | [valid] SSIM: 0.9437 | [valid] LPIPS: 0.0503
# Epoch: 3855 | learning rate: 0.000200 | [train] PSNR: 32.1193 | [train] SSIM: 0.9369 | [valid] PSNR: 31.7876 | [valid] SSIM: 0.9334 | [valid] LPIPS: 0.0552
# Epoch: 3966 | learning rate: 0.000200 | [train] PSNR: 32.1072 | [train] SSIM: 0.9368 | [valid] PSNR: 31.9686 | [valid] SSIM: 0.9380 | [valid] LPIPS: 0.0522
# Epoch: 4077 | learning rate: 0.000100 | [train] PSNR: 32.3261 | [train] SSIM: 0.9379 | [valid] PSNR: 32.8588 | [valid] SSIM: 0.9348 | [valid] LPIPS: 0.0597
# Epoch: 4188 | learning rate: 0.000100 | [train] PSNR: 32.0771 | [train] SSIM: 0.9377 | [valid] PSNR: 31.7589 | [valid] SSIM: 0.9348 | [valid] LPIPS: 0.0590
# Epoch: 4299 | learning rate: 0.000100 | [train] PSNR: 32.5066 | [train] SSIM: 0.9417 | [valid] PSNR: 32.7327 | [valid] SSIM: 0.9353 | [valid] LPIPS: 0.0565
# Epoch: 4410 | learning rate: 0.000100 | [train] PSNR: 32.2991 | [train] SSIM: 0.9399 | [valid] PSNR: 32.5617 | [valid] SSIM: 0.9370 | [valid] LPIPS: 0.0545
# Epoch: 4521 | learning rate: 0.000100 | [train] PSNR: 32.1669 | [train] SSIM: 0.9390 | [valid] PSNR: 33.0307 | [valid] SSIM: 0.9377 | [valid] LPIPS: 0.0566
# Epoch: 4632 | learning rate: 0.000100 | [train] PSNR: 32.1419 | [train] SSIM: 0.9408 | [valid] PSNR: 33.1809 | [valid] SSIM: 0.9432 | [valid] LPIPS: 0.0510
# Epoch: 4743 | learning rate: 0.000100 | [train] PSNR: 32.1297 | [train] SSIM: 0.9409 | [valid] PSNR: 32.4629 | [valid] SSIM: 0.9398 | [valid] LPIPS: 0.0518
# Epoch: 4786 | learning rate: 0.000100 | [train] PSNR: 32.3441 | [train] SSIM: 0.9400 | [valid] PSNR: 32.8933 | [valid] SSIM: 0.9486 | [valid] LPIPS: 0.0377
# Epoch: 4897 | learning rate: 0.000100 | [train] PSNR: 32.5823 | [train] SSIM: 0.9411 | [valid] PSNR: 32.0450 | [valid] SSIM: 0.9290 | [valid] LPIPS: 0.0589
# Epoch: 5008 | learning rate: 0.000100 | [train] PSNR: 32.4476 | [train] SSIM: 0.9413 | [valid] PSNR: 32.0346 | [valid] SSIM: 0.9353 | [valid] LPIPS: 0.0578
# Epoch: 5119 | learning rate: 0.000100 | [train] PSNR: 32.3179 | [train] SSIM: 0.9401 | [valid] PSNR: 32.8546 | [valid] SSIM: 0.9412 | [valid] LPIPS: 0.0499
# Epoch: 5230 | learning rate: 0.000100 | [train] PSNR: 32.4370 | [train] SSIM: 0.9406 | [valid] PSNR: 32.4613 | [valid] SSIM: 0.9373 | [valid] LPIPS: 0.0545
# Epoch: 5275 | learning rate: 0.000100 | [train] PSNR: 32.7336 | [train] SSIM: 0.9401 | [valid] PSNR: 34.1746 | [valid] SSIM: 0.9476 | [valid] LPIPS: 0.0445
# Epoch: 5386 | learning rate: 0.000100 | [train] PSNR: 32.5334 | [train] SSIM: 0.9391 | [valid] PSNR: 33.4402 | [valid] SSIM: 0.9446 | [valid] LPIPS: 0.0528
# Epoch: 5497 | learning rate: 0.000100 | [train] PSNR: 32.6752 | [train] SSIM: 0.9422 | [valid] PSNR: 32.1643 | [valid] SSIM: 0.9356 | [valid] LPIPS: 0.0570
# Epoch: 5608 | learning rate: 0.000100 | [train] PSNR: 32.3473 | [train] SSIM: 0.9411 | [valid] PSNR: 32.7435 | [valid] SSIM: 0.9413 | [valid] LPIPS: 0.0501
# Epoch: 5719 | learning rate: 0.000100 | [train] PSNR: 32.3186 | [train] SSIM: 0.9399 | [valid] PSNR: 31.7890 | [valid] SSIM: 0.9292 | [valid] LPIPS: 0.0628
# Epoch: 5830 | learning rate: 0.000100 | [train] PSNR: 32.5291 | [train] SSIM: 0.9393 | [valid] PSNR: 31.6607 | [valid] SSIM: 0.9346 | [valid] LPIPS: 0.0616
# Epoch: 5941 | learning rate: 0.000100 | [train] PSNR: 32.4676 | [train] SSIM: 0.9407 | [valid] PSNR: 32.1814 | [valid] SSIM: 0.9364 | [valid] LPIPS: 0.0564
# Epoch: 6052 | learning rate: 0.000100 | [train] PSNR: 32.3106 | [train] SSIM: 0.9395 | [valid] PSNR: 32.0287 | [valid] SSIM: 0.9356 | [valid] LPIPS: 0.0519
# Epoch: 6121 | learning rate: 0.000100 | [train] PSNR: 32.4781 | [train] SSIM: 0.9412 | [valid] PSNR: 34.5101 | [valid] SSIM: 0.9456 | [valid] LPIPS: 0.0484
# Epoch: 6232 | learning rate: 0.000100 | [train] PSNR: 32.1498 | [train] SSIM: 0.9394 | [valid] PSNR: 33.1047 | [valid] SSIM: 0.9373 | [valid] LPIPS: 0.0568
# Epoch: 6343 | learning rate: 0.000100 | [train] PSNR: 32.5502 | [train] SSIM: 0.9430 | [valid] PSNR: 31.5905 | [valid] SSIM: 0.9312 | [valid] LPIPS: 0.0578
# Epoch: 6454 | learning rate: 0.000100 | [train] PSNR: 32.5295 | [train] SSIM: 0.9403 | [valid] PSNR: 31.9285 | [valid] SSIM: 0.9355 | [valid] LPIPS: 0.0559
# Epoch: 6565 | learning rate: 0.000100 | [train] PSNR: 32.5606 | [train] SSIM: 0.9405 | [valid] PSNR: 32.5612 | [valid] SSIM: 0.9322 | [valid] LPIPS: 0.0612

# %%
checkpoint = torch.load('../tmp_model_checkpoints/last.pth')
model = ESRGAN(2).to(device)
model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
model.eval();

# %%
targets = [X32_valid_paths, X16_valid_paths, X8_valid_paths, X4_valid_paths, X2_valid_paths, HR_valid_paths]

metrics_x2 = pd.DataFrame(columns=["PSNR↑", "SSIM↑", "LPIPS↓"])
for target_ds in tqdm(targets, total=6):
    metrics_x2.loc[len(metrics_x2)] = calc_metrics(model, target_ds, 2)

metrics_x2.index = [
    "31px -> 62px", "63px -> 126px", "127px -> 254px", 
    "255px -> 510px", "510px -> 1020px", "1020px -> 2040px"
]
metrics_x2
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#                       PSNR↑     SSIM↑    LPIPS↓
# 31px -> 62px      26.885568  0.884635  0.049951
# 63px -> 126px     28.206117  0.901167  0.071395
# 127px -> 254px    30.141289  0.923697  0.073097
# 255px -> 510px    31.703115  0.932390  0.071856
# 510px -> 1020px   33.611977  0.942330  0.070376
# 1020px -> 2040px  34.819135  0.939396  0.084710

# %% [markdown]
# ### Day 3

# %%
train_dl = DataLoader(train_ds, batch_size=16, shuffle=True, num_workers=os.cpu_count()-1)
valid_dl = DataLoader(valid_ds, batch_size=16, shuffle=False, num_workers=os.cpu_count()-1)

checkpoint = torch.load('../tmp_model_checkpoints/last.pth')
model = ESRGAN(2).to(device)
loss_fn = nn.L1Loss()
optimizer = Adam(model.parameters(), lr=2e-4)
scheduler = StepLR(optimizer, step_size=4000, gamma=0.5)

model.load_state_dict(checkpoint['model_state_dict'])
model = torch.compile(model)
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
scheduler.load_state_dict(checkpoint['scheduler_state_dict'])

train(model, train_dl, valid_dl, optimizer, scheduler, loss_fn, 10000, checkpoint)

# %%
checkpoint = torch.load('../tmp_model_checkpoints/last.pth')
model = ESRGAN(2).to(device)
model.load_state_dict(checkpoint['model_state_dict'])

# %%
model.eval();

# %%
targets = [X32_valid_paths, X16_valid_paths, X8_valid_paths, X4_valid_paths, X2_valid_paths, HR_valid_paths]

metrics_x2 = pd.DataFrame(columns=["PSNR↑", "SSIM↑", "LPIPS↓"])
for target_ds in tqdm(targets, total=6):
    metrics_x2.loc[len(metrics_x2)] = calc_metrics(model, target_ds, 2)

metrics_x2.index = [
    "31px -> 62px", "63px -> 126px", "127px -> 254px", 
    "255px -> 510px", "510px -> 1020px", "1020px -> 2040px"
]
metrics_x2

# %% [markdown]
# ### Day 4

# %%
train_dl = DataLoader(train_ds, batch_size=16, shuffle=True, num_workers=os.cpu_count()-1)
valid_dl = DataLoader(valid_ds, batch_size=16, shuffle=False, num_workers=os.cpu_count()-1)

checkpoint = torch.load('../tmp_model_checkpoints/last.pth')
model = ESRGAN(2).to(device)
loss_fn = nn.L1Loss()
optimizer = Adam(model.parameters(), lr=2e-4)
scheduler = StepLR(optimizer, step_size=4000, gamma=0.5)

model.load_state_dict(checkpoint['model_state_dict'])
model = torch.compile(model)
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
scheduler.load_state_dict(checkpoint['scheduler_state_dict'])

train(model, train_dl, valid_dl, optimizer, scheduler, loss_fn, 13333, checkpoint)

# %%
checkpoint = torch.load('../tmp_model_checkpoints/last.pth')
model = ESRGAN(2).to(device)
model.load_state_dict(checkpoint['model_state_dict'])

# %%
model.eval();

# %%
targets = [X32_valid_paths, X16_valid_paths, X8_valid_paths, X4_valid_paths, X2_valid_paths, HR_valid_paths]

metrics_x2 = pd.DataFrame(columns=["PSNR↑", "SSIM↑", "LPIPS↓"])
for target_ds in tqdm(targets, total=6):
    metrics_x2.loc[len(metrics_x2)] = calc_metrics(model, target_ds, 2)

metrics_x2.index = [
    "31px -> 62px", "63px -> 126px", "127px -> 254px", 
    "255px -> 510px", "510px -> 1020px", "1020px -> 2040px"
]
metrics_x2

# %% [markdown]
# ### Day 5

# %%
train_dl = DataLoader(train_ds, batch_size=16, shuffle=True, num_workers=os.cpu_count()-1)
valid_dl = DataLoader(valid_ds, batch_size=16, shuffle=False, num_workers=os.cpu_count()-1)

checkpoint = torch.load('../tmp_model_checkpoints/last.pth')
model = ESRGAN(2).to(device)
loss_fn = nn.L1Loss()
optimizer = Adam(model.parameters(), lr=2e-4)
scheduler = StepLR(optimizer, step_size=4000, gamma=0.5)

model.load_state_dict(checkpoint['model_state_dict'])
model = torch.compile(model)
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
scheduler.load_state_dict(checkpoint['scheduler_state_dict'])

train(model, train_dl, valid_dl, optimizer, scheduler, loss_fn, 16666, checkpoint)

# %%
checkpoint = torch.load('../tmp_model_checkpoints/last.pth')
model = ESRGAN(2).to(device)
model.load_state_dict(checkpoint['model_state_dict'])

# %%
model.eval();

# %%
targets = [X32_valid_paths, X16_valid_paths, X8_valid_paths, X4_valid_paths, X2_valid_paths, HR_valid_paths]

metrics_x2 = pd.DataFrame(columns=["PSNR↑", "SSIM↑", "LPIPS↓"])
for target_ds in tqdm(targets, total=6):
    metrics_x2.loc[len(metrics_x2)] = calc_metrics(model, target_ds, 2)

metrics_x2.index = [
    "31px -> 62px", "63px -> 126px", "127px -> 254px", 
    "255px -> 510px", "510px -> 1020px", "1020px -> 2040px"
]
metrics_x2

# %% [markdown]
# ### Day 6

# %%
train_dl = DataLoader(train_ds, batch_size=16, shuffle=True, num_workers=os.cpu_count()-1)
valid_dl = DataLoader(valid_ds, batch_size=16, shuffle=False, num_workers=os.cpu_count()-1)

checkpoint = torch.load('../tmp_model_checkpoints/last.pth')
model = ESRGAN(2).to(device)
loss_fn = nn.L1Loss()
optimizer = Adam(model.parameters(), lr=2e-4)
scheduler = StepLR(optimizer, step_size=4000, gamma=0.5)

model.load_state_dict(checkpoint['model_state_dict'])
model = torch.compile(model)
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
scheduler.load_state_dict(checkpoint['scheduler_state_dict'])

train(model, train_dl, valid_dl, optimizer, scheduler, loss_fn, 20000, checkpoint)

# %%
checkpoint = torch.load('../tmp_model_checkpoints/last.pth')
model = ESRGAN(2).to(device)
model.load_state_dict(checkpoint['model_state_dict'])

# %%
model.eval();

# %%
targets = [X32_valid_paths, X16_valid_paths, X8_valid_paths, X4_valid_paths, X2_valid_paths, HR_valid_paths]

metrics_x2 = pd.DataFrame(columns=["PSNR↑", "SSIM↑", "LPIPS↓"])
for target_ds in tqdm(targets, total=6):
    metrics_x2.loc[len(metrics_x2)] = calc_metrics(model, target_ds, 2)

metrics_x2.index = [
    "31px -> 62px", "63px -> 126px", "127px -> 254px", 
    "255px -> 510px", "510px -> 1020px", "1020px -> 2040px"
]
metrics_x2
